# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('images\\base\\square.png', cv2.IMREAD_GRAYSCALE)

# Define the center and radius for the polar transformation
center = (image.shape[1] // 2, image.shape[0] // 2)
radius = np.sqrt(center[0]**2 + center[1]**2)

# Apply the polar transformation
polar_image = cv2.linearPolar(image, center, radius, cv2.WARP_FILL_OUTLIERS)

# Visualize the result
plt.imshow(polar_image, cmap='gray')
plt.title('Polar Coordinates')
plt.show()
